# %% [markdown]
# # Introducción a la librería de Pandas
# ----------------------
#
# ### Data Fundamentals con Python
#
# #### Enero 2023
#
# **Aurora Cobo Aguilera**
#
# **The Valley**
#
# ----------------------

# %% [markdown]
# ## Empezamos con un ejemplo guiado
#
# En este notebook vamos a ver una introducción de la librería de Pandas.
#
# Para ello primero vamos a importar las librerías que vamos a usar, pandas y la que ya conoces de numpy.

# %%
import pandas as pd

# %% [markdown]
# A continuación leemos fichero de datos con Pandas. Para ello acuérdate de subirlo a la nube previamente.

# %%
chipo = pd.read_csv('chipotle.tsv', sep = '\t')

# %% [markdown]
# Quédate bien con esa línea de código. simplemente tendrás que sustituir los parámetros por los valores adecuados en cada situación.
#
# Veamos qué pinta tienen los datos.

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# Ahora *chipo* es un tipo de datos especial, denominado **dataframe** que permite nuevas funcionalidades para tratar la tabla con la infromación del fichero leído.
#
# Por ejemplo, *head* muestra las 5 primeras líneas.

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# Como puedes comprobar, existe valores NaN, que son consideramos nulos para nosotros. Pandas ofrece una funcionalidad para eliminarlos.

# %%
chipo = chipo.dropna() 
chipo
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [3376 rows x 5 columns]

# %% [markdown]
# > **Ejercicio**: ¿Sabrías decirme qué porcentaje de observaciones con nulos había y se han eliminado?

# %%
round(((1-(3376/4622))*100),2)
# Out:
# 26.96

# %% [markdown]
# *info* nos dice alguna información sobre nuestro dataframe, como los campos que tiene y el tipo de datos de cada uno.

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3376 entries, 1 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            3376 non-null   int64
#  1   quantity            3376 non-null   int64
#  2   item_name           3376 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          3376 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 158.2+ KB

# %% [markdown]
# El atributo *columns* nos da el nombre de las columnas:

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# y con esta información podríamos acceder a los elementos de cualquier columna.

# %%
chipo.order_id
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#         ...
# 4617    1833
# 4618    1833
# 4619    1834
# 4620    1834
# 4621    1834
# Name: order_id, Length: 4622, dtype: int64

# %% [markdown]
# incluso operar con ellos.

# %% [markdown]
# La siguiente instrucción nos dice cuántos identificadores de orden diferentes hay.

# %%
orders = chipo.order_id.value_counts().count()
orders
# Out:
# 1834

# %% [markdown]
# Otra funcionalidad muy potente de pandas es poder definir una función que aplicar a todos los elementos de una columna. Funciona de la siguiente manera.

# %%
chipo.item_price[1]
# Out:
# '$3.39 '

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %%
chipo.item_price
# Out:
# 1        3.39
# 2        3.39
# 4       16.98
# 5       10.98
# 7       11.75
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 3376, dtype: float64

# %% [markdown]
# Por ejemplo, el código anterior, convierte a float la cantidad de dinero en formato string. Mira cómo cambia la información ahora:

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3376 entries, 1 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            3376 non-null   int64
#  1   quantity            3376 non-null   int64
#  2   item_name           3376 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          3376 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 287.3+ KB

# %% [markdown]
# También podemos crear columnas nuevas.
#
# > **Ejercicio**: Observa la siguiente instrucción, ¿qué estará haciendo?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
chipo
# Out:
# <ipython-input-20-24820e504d50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chipo['revenue'] = chipo['quantity'] * chipo['item_price']
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price  revenue
# 1                                          [Clementine]        3.39     3.39
# 2                                               [Apple]        3.39     3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98    10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75    11.75
# ...                                                 ...         ...      ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75    11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75    11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25    11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75     8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75     8.75
#
# [3376 rows x 6 columns]

# %% [markdown]
# Ahora el *head* ha cambiado

# %%
chipo.head()
# Out:
#    order_id  quantity         item_name  \
# 1         1         1              Izze
# 2         1         1  Nantucket Nectar
# 4         2         2      Chicken Bowl
# 5         3         1      Chicken Bowl
# 7         4         1     Steak Burrito
#
#                                   choice_description  item_price  revenue
# 1                                       [Clementine]        3.39     3.39
# 2                                            [Apple]        3.39     3.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98    10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75    11.75

# %% [markdown]
# Podemos realizar operaciones más complejas.
#
# > **Ejercicio**: Investiga qué hace lo siguiente.

# %%
chipo.groupby(by=['order_id']).sum().mean()['revenue']
# Out:
# 18.33168576104746

# %%
chipo.head()
# Out:
#    order_id  quantity         item_name  \
# 1         1         1              Izze
# 2         1         1  Nantucket Nectar
# 4         2         2      Chicken Bowl
# 5         3         1      Chicken Bowl
# 7         4         1     Steak Burrito
#
#                                   choice_description  item_price  revenue
# 1                                       [Clementine]        3.39     3.39
# 2                                            [Apple]        3.39     3.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98    10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75    11.75

# %% [markdown]
# > **Ejericio**: ¿Y la siguiente instrucción?

# %%
chipo.item_name.value_counts().count()
# Out:
# 38

# %% [markdown]
# ## Fichero en JSON
#
# Podemos hacer algo parecido si el fichero qeu tenemos está en un formato JSON. Por ejemplo, el siguiente, que creamos de forma manual.

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# Esta vez, como no leemos fichero, sino que tenemos la estructura de datos ya creada en Python, usamos el siguiente comando para convertirla en dataframe.

# %%
army = pd.DataFrame(data=raw_data)
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %% [markdown]
# Ahora que tiene la misma pinta que el ejemplo anterior, podríamos hacer algo parecido. Por ejemplo, seleccionar lso datos de 3 columnas concretas.

# %%
army[ ["size",'deaths', "veterans"] ]
# Out:
#     size  deaths  veterans
# 0   1045     523         1
# 1    957      52         5
# 2   1099      25        62
# 3   1400     616        26
# 4   1592      43        73
# 5   1006     234        37
# 6    987     523       949
# 7    849      62        48
# 8    973      62        48
# 9   1005      73       435
# 10  1099      37        63
# 11  1523      35       345

# %%
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters', 'origin'],
#       dtype='object')

# %% [markdown]
# *iloc* permite acceder a posiciones concretas de la tabla.

# %%
army.iloc[:7, ] #Filas, Columnas
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 2  Nighthawks     2nd      25        2  1099        62          3        1
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 4    Dragoons     1st      43        4  1592        73          2        0
# 5    Dragoons     1st     234        7  1006        37          1        1
# 6    Dragoons     2nd     523        8   987       949          2        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 2         31       Texas
# 3          2     Florida
# 4          3       Maine
# 5          4        Iowa
# 6         24      Alaska

# %%
army.iloc[:, 2:]
# Out:
#     deaths  battles  size  veterans  readiness  armored  deserters      origin
# 0      523        5  1045         1          1        1          4     Arizona
# 1       52       42   957         5          2        0         24  California
# 2       25        2  1099        62          3        1         31       Texas
# 3      616        2  1400        26          3        1          2     Florida
# 4       43        4  1592        73          2        0          3       Maine
# 5      234        7  1006        37          1        1          4        Iowa
# 6      523        8   987       949          2        0         24      Alaska
# 7       62        3   849        48          3        1         31  Washington
# 8       62        4   973        48          2        0          2      Oregon
# 9       73        7  1005       435          1        0          3     Wyoming
# 10      37        8  1099        63          2        1          2    Louisana
# 11      35        9  1523       345          3        1          3     Georgia

# %%
army[ (army['deaths'] > 50) ] # & = and. | = or.
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 5    Dragoons     1st     234        7  1006        37          1        1
# 6    Dragoons     2nd     523        8   987       949          2        0
# 7    Dragoons     2nd      62        3   849        48          3        1
# 8      Scouts     1st      62        4   973        48          2        0
# 9      Scouts     1st      73        7  1005       435          1        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 3          2     Florida
# 5          4        Iowa
# 6         24      Alaska
# 7         31  Washington
# 8          2      Oregon
# 9          3     Wyoming

# %% [markdown]
# ## A practicar!

# %%
import pandas as pd
import datetime

# %% [markdown]
# Vamos, en primer lugar a cargar y leer el fichero en un dataframe.

# %%
data = pd.read_csv('wind.data', sep = "\s+", parse_dates = [[0,1,2]]) 
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %% [markdown]
# > **Ejercicio**: Investiga qué hace la instrucción 'parse_dates = [[0,1,2]]'. ¿Qué ha pasado con la fecha? ¿Cómo puede haber fechas con el año 2061?. Algo va mal. Primero corrige el error. Crea una función para ello y aplícala a los elementos de la columna apropiada. Completa el siguiente fragmento de código.

# %%
# Funciones de corregir columnas...

def fix_century(x):
  #year = x.year-100 if x.year>2000 else year=x.year
  if x.year>2000:
    year=x.year-100
  else:
    year=x.year

  return datetime.date(year, x.month, x.day)

# Otro apply :D
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_century) #<SOL>

# data.info()
data.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# A continuación, vamos a seleccionar el campo de la fecha como índice.

# %%
# Transformamos Yr_Mo_Dy a tipo de datos fecha= datetime64
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])

#  'Yr_Mo_Dy' Cimo indice...
data = data.set_index('Yr_Mo_Dy')

data.head()
# data.info()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# > **Ejercicio**: ¿Cuántos valores nulos hay?

# %%
data.isnull().sum().sum()
# Out:
# 31

# %% [markdown]
# > **Ejercicio**: ¿Y no nulos?

# %%
data.notnull().sum().sum()

#</SOL>
# Out:
# 78857

# %% [markdown]
# > **Ejercicio**: Por último, calcula la media de cada columna cuando la fecha tenga el mes de junio. Usa la función *loc* de los dataframes.

# %%
from numpy.core.fromnumeric import mean
mediaJunio=data.loc[data.index.month==6].mean()
mediaJunio
# Out:
# RPT    10.451317
# VAL     8.949704
# ROS    10.361315
# KIL     5.652278
# SHA     9.529926
# BIR     6.410093
# DUB     8.009556
# CLA     7.920796
# MUL     7.639796
# CLO     7.729185
# BEL    12.246407
# MAL    12.861818
# dtype: float64
