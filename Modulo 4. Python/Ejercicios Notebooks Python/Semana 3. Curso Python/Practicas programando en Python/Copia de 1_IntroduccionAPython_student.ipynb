# %% [markdown]
# # Introducción a Python
#
# ### Data Fundamentals con Python
#
# #### Enero 2023
#
# **Aurora Cobo Aguilera**
#
# **The Valley**
#
# -----------------------------

# %% [markdown]
# ## Cuadernos o *notebooks*.
#
# En este primer cuaderno, vamos a empezar a familiarizarnos con el lenguaje de programación de Python. Antes de nada debes saber qué es un cuaderno o *notebook* pues los usaremos constantemente en el bloque de Python y de *Machine Learning*.
#
# Un notebook se compone de celdas de texto o de código. La principal ventaja es la facilidad de poder separar secciones de código y texto de manera que puedas ejecutar código y acompañarlo de descripciones que los detallan.

# %% [markdown]
# ## 1. Primeras líneas de código

# %% [markdown]
# Una asignación no es una ecuación.

# %%
x = 3
x = x + 1

# %% [markdown]
# > **Ejercicio**: Antes de ejecutar la siguiente celda, qué valor crees que tiene x?

# %%
x
# Out:
# 4

# %% [markdown]
# > **Ejercicio**: Evalúa el polinomio $x^4+x^3+2x^2-x$ en x=1.1. Utiliza variables para ejecutar varias veces el valor de x. (Resultado 4.1151)

# %%
#<SOL>
dato = 1.1
resultado = dato**4 + dato**3 + 2 * dato**2 - dato
resultado
#</SOL>
# Out:
# 4.115100000000002

# %% [markdown]
# > **Ejercicio**: Evalúa el polinomio $x^4+x^3+\frac{1}{2}x^2-x$ en x=10. Utiliza variables para ejecutar varias veces el valor de x. (Resultado 11040.0)

# %%
#<SOL>
x = 10
resultado = x**4 + x**3 + 1/2 * x**2 - x
resultado
#</SOL>
# Out:
# 11040.0

# %% [markdown]
# ### 1.1 Incremento de una variable con cierta cantidad: +=
# Puedes incrementar el valor de cualquier variable de la siguiente manera

# %%
x = 0
x += 1       # Esto es lo mismo que         x = x + 1
x
# Out:
# 1

# %%
a = 3
b = 2
a += 4 * b
a
# Out:
# 11

# %% [markdown]
# ### 1.2 Formas compactas
# Lo mismo se puede aplicar a cualquier operador

# %% [markdown]
# > **Ejercicio**: Qué valor tiene z después de las siguientes sentencias?

# %%
z = 2
z += 2  #4
z += 2 - 2  #4
z *= 2  #8
z *= 1 + 1  #16
z //= 2 #8
z %= 3  #2
z /= 3 - 1  #1
z -= 2 + 1  #-2
z -= 2    #-4
z *= 3  #-12
z
# Out:
# -12.0

# %% [markdown]
# ## 2.Cadenas de texto
#
# Pueden ir entre comillas simples o dobles y también se pueden hacer operaciones con ellas.

# %%
miCadena = 'Esto es una cadena\" de prueba'
miCadena
# Out:
# 'Esto es una cadena" de prueba'

# %%
'a' + 'b'
# Out:
# 'ab'

# %%
nombre = 'Pepe'
print(nombre + 'Cano')
# Out:
# PepeCano

# %%
nombre + ' ' + 'Cano'
# Out:
# 'Pepe Cano'

# %% [markdown]
# No confundamos las cadenas con variables:

# %%
a = 1

# %%
'a'
# Out:
# 'a'

# %%
a
# Out:
# 1

# %% [markdown]
# No olvidar las comillas!

# %%
Pepe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0e94b8801d41> in <module>
# ----> 1 Pepe
#
# NameError: name 'Pepe' is not defined

# %% [markdown]
# Ni ponerlas cuando no debes

# %%
'x' = 2
# Out:
#   File "<ipython-input-30-171badc3e1dc>", line 1
#     'x' = 2
#     ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# Recuerda: sólo se pueden asignar valores a variables, y las cadenas no son identificadores.

# %% [markdown]
# Es importante distinguir esto así como la diferencia de aplicar el operador + a números y a cadenas (concatenar).

# %%
'12' + '12'
# Out:
# '1212'

# %%
12 + 12
# Out:
# 24

# %% [markdown]
# Por último, también se puede usar el operador * con cadenas. Es el operador de repetición y se acompaña de un número que indica las veces que queremos concatenar y repetir una cadena.

# %%
'Hola' * 5
# Out:
# 'HolaHolaHolaHolaHola'

# %% [markdown]
# > **Ejercicio**: Evalúa las siguientes sentencias y predice la salida antes de ejecutar:

# %%
a = 'b'
a + 'b'
# Out:
# 'bb'

# %%
a + 'a'
# Out:
# 'ba'

# %%
a * 2 + 'b' * 3
# Out:
# 'bbbbb'

# %%
2 * (a + 'b')
# Out:
# 'bbbb'

# %%
2 * ('a' + 'b')
# Out:
# 'abab'

# %% [markdown]
# > **Ejercicio**: Repite lo mismo con las siguientes expresiones:

# %%
'a' * 3 + '/*' * 5 + 2 * 'abc' + '+'
# Out:
# 'aaa/*/*/*/*/*abcabc+'

# %%
palindromo = 'abcba'
(4 * '<' + palindromo + '>' * 4) * 2
# Out:
# '<<<<abcba>>>><<<<abcba>>>>'

# %%
subcadena = '=' + '_' * 3 + '='
'10' * 5 + 4 * subcadena
# Out:
# '1010101010=___==___==___==___='

# %%
2 * '12' + '.' + 3 * '3' + 'e-' + 4 * '76'
# Out:
# '1212.333e-76767676'

# %% [markdown]
# > **Ejercicio**: Identifica regularidades en las siguientes cadenas, y escribe expresiones que, partiendo de subcadenas más cortas y utilizando los operadores de concatenación y repetición, produzcan las cadenas que se muestran. Introduce variables para formar las expresiones cuando lo consideres oportuno.

# %% [markdown]
# > %%%%%./././<-><->

# %%
#<SOL>
5*'%'+3*'./'+2*'<->'
#</SOL>
# Out:
# '%%%%%./././<-><->'

# %% [markdown]
# >(@)(@)(@)======(@)(@)(@)======

# %%
#<SOL>
aux = 3*'(@)'+6*'='
2 * aux
#</SOL>
# Out:
# '(@)(@)(@)======(@)(@)(@)======'

# %% [markdown]
# > asdfasdfasdf=-=-=-=-=-=-=-??????asdfasdf

# %%
#<SOL>
aux = 'asdf'
aux * 3 + '=-' * 7 + '?' * 6 + aux * 2
#</SOL>
# Out:
# 'asdfasdfasdf=-=-=-=-=-=-=-??????asdfasdf'

# %% [markdown]
# ## 3. Funciones predefinidas

# %%
abs(-23)
# Out:
# 23

# %%
abs(-23) % int(7.3)     # 23 % 7
# Out:
# 2

# %%
round(-34.2765, 1)
# Out:
# -34.3

# %%
abs(round(-34.2765, 1))
# Out:
# 34.3

# %%
str(float(str(2) * 3 + '.123')) + '321'     # '222.123321'
# Out:
# '222.123321'

# %% [markdown]
# > **Ejercicio**: Calcula con una sola expresión el resultado del redondeo del valor absoluto de -3.2. El resultado es 3.

# %%
round(abs(-3.2))
# Out:
# 3

# %% [markdown]
# > **Ejercicio**: Convierte a cadena el resultado de la división 5011/10000 redondeado con 3 decimales.

# %%
str(round((5011/10000),3))
# Out:
# '0.501'

# %% [markdown]
# > **Ejercicio**: ¿Qué resulta de evaluar estas expresiones?

# %%
str(2.1) + str(1.2)
# Out:
# '2.11.2'

# %%
int(str(2) + str(3))
# Out:
# 23

# %%
str(int(12.3)) + '0'
# Out:
# '120'

# %%
int('2' + '3')
# Out:
# 23

# %%
str(2 + 3)
# Out:
# '5'

# %%
str(int(2.1) + float(3))
# Out:
# '5.0'

# %% [markdown]
# ## 4. Módulos

# %%
from math import sin, pi

# %%
sin(pi)

# %% [markdown]
# ## 5. Datos de entrada por teclado
#
# En Python es posible escribir un programa que te solicite datos de entrada por teclado, para ello se utiliza la función *input()*. Mira el siguiente ejemplo

# %%
a = float(input('Dame un número: '))
b = float(input('Dame otro número: '))
c = float(input('Y ahora, uno más: '))
media = (a+b+c) / 3
print('La media es ', media)

# %% [markdown]
# ## 6. Mostrar datos y resultados
# Para mostrar algún texto durante el programa o inlcuso el valor de una variable podemos usar *print()*. En esta función debes pasar un string o cadena, con o sin formato (usando *format*). Mira el siguiente ejemplo.

# %%
print('Esto es un print en python y aquí puedes escribir lo que quieras*')

# %%
num = 3.2244
print('incluso el valor de la variable num = {0:.2f}'.format(num))
print('o también lo puedes meter aquí ', num, ' en medio!')

# %% [markdown]
# ## 7. Comentarios y repaso

# %%
# Propósito: Calcula el perímetro y el área de un rectángulo a partir de su altura y anchura.
# Autor: John Cleese
# Fecha: 1/1/2010

# Petición de los datos (en metros)
altura = float(input('Dame la altura en metros: '))
anchura = float(input('Dame la anchura en metros: '))

# Cálculo del área y del perímetro
area = altura * anchura
perimetro = 2 * altura + 2 * anchura

# Impresión de resultados por pantalla
print('El perímetro es de {0:1.2f} metros'.format(perimetro))
print('El área es de {0:1.2f} metros cuadrados'.format(area))
# Out:
# Dame la altura en metros: 2
# Dame la anchura en metros: 5
# El perímetro es de 14.00 metros
# El área es de 10.00 metros cuadrados

# %% [markdown]
# ## Te toca practicar!!

# %% [markdown]
# > **Ejercicio**: Diseña un programa que, a partir del valor del lado de un cuadrado (3 metros), muestre el valor de su perímetro (en metros) y el de su área (en metros cuadrados). Muestra los resultados con *print*. Resultado: 12 y 9.

# %%
lado= 3
perimetro= 4*lado
area= lado**2
print('El valor del perimetro es {1} metros y el area es {2} metros cuadrados'.format(lado,perimetro,area))
# Out:
# El valor del perimetro es 12 metros y el area es 9 metros cuadrados

# %% [markdown]
# > **Ejercicio**: Escribe un programa que lea de teclado el valor de un radio y te muestre por pantalla el área de dicho círculo. Para ello usa la librería *math* con su correspondientes *import* y usa también la función *input()*

# %%
radio= float(input('ingrese el valor numerico del radio:'))
from math import pi
area= pi*radio**2
print('El valor del area es {} metros cuadrados'.format(area))
# Out:
# ingrese el valor numerico del radio:2
# El valor del area es 12.566370614359172 metros cuadrados

# %% [markdown]
# > **Ejercicio**: Diseña un programa que pida por teclado el valor de la base y la altura de un triángulo y muestre el valor de su área.

# %%
base= float(input('ingrese el valor de la base del triangulo:'))
altura= float(input('ingrese el valor de la altura del triangulo:'))
areatriangulo= base*altura/2
print('El valor del area del triangulo es {} metros cuadrados'.format(areatriangulo))
# Out:
# ingrese el valor de la base del triangulo:2
# ingrese el valor de la altura del triangulo:3
# El valor del area del triangulo es 3.0 metros cuadrados

# %% [markdown]
# ## 8. Estructuras de control

# %% [markdown]
# > **Ejercicio**: Diseña un programa que lea un número flotante por teclado y muestre por pantalla el mensaje 'El número es positivo' sólo si el número es mayor o igual que cero.

# %%
x=float(input('ingrese un numero: '))

if x>=0:
  print('el numero es positivo')
elif x<0:
  print('el numero es negativo')
else:
  print('inserte un numero')
# Out:
# ingrese un numero: -5.
# el numero es negativo

# %% [markdown]
# > **Ejercicio**: Escribe un programa que lea la edad de dos personas y diga quién es más joven, la primera o la segunda. Ten en cuenta que ambas pueden tener la misma edad. En tal caso, hazlo saber con un mensaje adecuado.

# %%
x=int(input('ingrese la edad de la primera persona: '))
y=int(input('ingrese la edad de la segunda persona: '))

if x>y:
  print('La persona 1 es mayor que la persona 2')
elif x<y:
  print('La persona 2 es mayor que la persona 1')

else: 
  print('Las personas tienen la misma edad')
# Out:
# ingrese la edad de la primera persona: 20
# ingrese la edad de la segunda persona: 20
# Las personas tienen la misma edad

# %% [markdown]
# > **Ejercicio MÁS DIFICIL!!:** Diseñe un programa que, dado un número entero, determine si éste es el doble de un número impar.

# %%
x=int(input('ingrese un numero entero:'))
b=x/2 
a=b % 2
if a==1:
  print('El numero ingresado es el doble del numero impar: {}'.format(b))

else:
  print('El numero ingresado no es el doble de un numero impar')
# Out:
# ingrese un numero entero:5
# El numero ingresado no es el doble de un numero impar

# %% [markdown]
# > **Ejercicio EXTRA!**: Realiza un programa que calcule el desglose mínimo en billetes y monedas de una cantidad exacta de euros. Hay billetes de 500, 200, 100, 50, 20, 10 y 5 € y monedas de 2 y 1 €.
# Por ejemplo, si deseamos conocer el desglose de 434 €, el programa mostrará por pantalla el siguiente resultado:
#
# *2 billetes de 200 euros*
#
# *1 billete de 20 euros*
#
# *1 billete de 10 euros*
#
# *2 monedas de 2 euros*

# %%
dinero_total = int(input('introduce el importe en euros'))

for billete in [500,200,100,50,20,10,5,2,1]:
  if dinero_total >= billete:
    num_billetes = dinero_total // billete
    dinero_total = dinero_total % billete
    if billete < 5: 
      print(num_billetes,'moneda(s) de', billete)
    else:
      print(num_billetes, 'billete(s) de',billete)
# Out:
# introduce el importe en euros8432
# 16 billete(s) de 500
# 2 billete(s) de 200
# 1 billete(s) de 20
# 1 billete(s) de 10
# 1 moneda(s) de 2

# %% [markdown]
# > **Ejercicio**: Diseña un programa que lea un carácter cualquiera desde teclado y muestre el mensaje 'Es una mayúscula' cuando el carácter sea una letra mayúscula y 'Es una minúscula' cuando sea minúscula. En cualquier otro caso debe mostrar 'No es una letra'.

# %%
caracter=str(input('ingrese un caracter desde el teclado:'))

min= 'a,b,c,d,e,f,g,h,i,j,k,l,m,n,ñ,o,p,q,r,s,t,u,v,w,x,y,z'
may='A,B,C,D,E,F,G,H,I,J,K,L,M,N,Ñ,O,P,Q,R,S,T,U,V,W,X,Y,Z'

b=len(caracter)

if b==1:

  if caracter in (min):
    print('Es una letra minùscula')

  elif caracter in (may):
    print('Es una letra mayùscula')

  else:
    print('no ha ingresado una letra')


else: 

  print('ingrese un solo caracter')
# Out:
# ingrese un caracter desde el teclado:AD
# ingrese un solo caracter

# %% [markdown]
# > **Ejercicio**: Diseña un programa que calcule el máximo de 5 números enteros.

# %%
valor1= int(input('ingrese el valor del 1er numero entero:')) 
valor2= int(input('ingrese el valor del 2do numero entero:'))
valor3= int(input('ingrese el valor del 3er numero entero:'))
valor4= int(input('ingrese el valor del 4to numero entero:'))
valor5= int(input('ingrese el valor del 5to numero entero:'))

x=list((valor1,valor2,valor3,valor4,valor5))
máximo= max(x)
print('El numero mayor es:{}'.format(máximo))
# Out:
# ingrese el valor del 1er numero entero:1
# ingrese el valor del 2do numero entero:2
# ingrese el valor del 3er numero entero:3
# ingrese el valor del 4to numero entero:4
# ingrese el valor del 5to numero entero:5
# El numero mayor es:5

# %% [markdown]
# > **Ejercicio**: Diseñe un programa que, dados 5 números enteros, determine cuál de los 4 últimos números es más cercano al primero.

# %%
num1= int(input('ingrese el numero 1:'))
num2= int(input('ingrese el numero 2:'))
num3= int(input('ingrese el numero 3:'))
num4= int(input('ingrese el numero 4:'))
num5= int(input('ingrese el numero 5:'))


resto2= abs(num1-num2)
resto3= abs(num1-num3)
resto4= abs(num1-num4)
resto5= abs(num1-num5)

if resto2<=resto3 and resto2<=resto4 and resto2<=resto5:
  print('El numero 2 es el mas cercano. El numero es:', num2)
        
elif resto3<=resto2 and resto3<=resto4 and resto4<=resto5:
  print('El numero 3 es el mas cercano. El numero es:', num3) 

elif resto4<=resto2 and resto4<=resto3 and resto4<=resto5:
  print('El numero 4 es el mas cercano. El numero es:', num4) 

elif resto5<=resto2 and resto5<=resto4 and resto5<=resto3:
  print('El numero 5 es el mas cercano. El numero es:', num5)
# Out:
# ingrese el numero 1:2
# ingrese el numero 2:4
# ingrese el numero 3:-8
# ingrese el numero 4:5
# ingrese el numero 5:6
# El numero 2 es el mas cercano. El numero es: 4

# %% [markdown]
# >**Ejercicio**: Implementa un programa que muestre todos los múltiplos de 6 entre 6 y 150, ambos inclusive.

# %%
lista= list(range(6,151,1))
lista2=[]
for a in lista:
  if a%6==0:
    lista2.append(a)

print (lista2)
# Out:
# [6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96, 102, 108, 114, 120, 126, 132, 138, 144, 150]

# %% [markdown]
# > **Ejercicio**: Diseñe un programa que sume los 100 primeros números.

# %%
a= list(range(1,101,1))

b=sum(a)

print('la suma de los 100 primeros numeros es: ',b)
# Out:
# la suma de los 100 primeros numeros es:  5050

# %% [markdown]
# > **Ejercicio**: Diseñe un programa que muestre la tabla de multiplicar de un número introducido por teclado.

# %%
a=int(input('introduzca un numero entero'))

b=a*1
c=a*2
d=a*3
e=a*4
f=a*5
g=a*6
h=a*7
j=a*8
k=a*9
l=a*10
print('{0}*1={1}'.format(a,b))
print('{0}*2={1}'.format(a,c))
print('{0}*3={1}'.format(a,d))
print('{0}*4={1}'.format(a,e))
print('{0}*5={1}'.format(a,f))
print('{0}*6={1}'.format(a,g))
print('{0}*7={1}'.format(a,h))
print('{0}*8={1}'.format(a,j))
print('{0}*9={1}'.format(a,k))
print('{0}*10={1}'.format(a,l))
# Out:
# introduzca un numero entero38
# 38*1=38
# 38*2=76
# 38*3=114
# 38*4=152
# 38*5=190
# 38*6=228
# 38*7=266
# 38*8=304
# 38*9=342
# 38*10=380

# %% [markdown]
# > **Ejercicio**: Diseñe un programa para calcular si un número es primo o no.

# %%
num=int(input('ingrese un numero:'))

for n in range(2,num):
  if num%n==0:
    print('el numero no es primo, es divisible por',n)
    break
  
  else:
    print('el numero es primo')
    break
# Out:
# ingrese un numero:7
# el numero es primo
